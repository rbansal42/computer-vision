# %%
# Installing Dependencies

# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing required packages

import cv2
print("Successfully imported")
# Out:
# Successfully imported

# %%
# Reading image

OG_img = cv2.imread("img.jpg")
print("Image read successfully")
# Out:
# Image read successfully

# %%
gray_image = cv2.cvtColor(OG_img, cv2.COLOR_BGR2GRAY) #converting the image into grey scale

# %%
a = cv2.imwrite("img2.jpg", gray_image) #to save the image

# %%
cv2.imshow("img", OG_img)
wait = True
while wait:
  wait = cv2.waitKey()=='q113' # hit q to exit

# %%
#draw a line on the image
lined_img = cv2.line(img, (0,0), (255,255), (0,0,255), 5) #(0,0) is the starting point
#(255,255) is the ending pt
#0,0,255 is RGB color
#5 is the thickness

# %%
cv2.imshow("lined_image", img)
wait = True
while wait:
  wait = cv2.waitKey()=='q113' # hit q to exit

# %%
#arrowed line
img = cv2.arrowedLine(img, (0,255), (255,255), (255,0,0), 6)
cv2_imshow(img)

# %%
#rectangle
img = cv2.rectangle(img, (384,0), (510,128), (0,255,0), 1)
cv2_imshow(img)

# %%
#circle
img = cv2.circle(img,(447,63),63,(0,255,0), -1)
cv2_imshow(img)

# %%
#text on the image
font = cv2.FONT_HERSHEY_COMPLEX
img = cv2.putText(img,'Sushant',(10,50),font,4,(255,255,0),10,cv2.LINE_AA)
#10,50 is the location
#4 is the font size
#255,255,0 is color
#10 is the font thickness


cv2_imshow(img)
